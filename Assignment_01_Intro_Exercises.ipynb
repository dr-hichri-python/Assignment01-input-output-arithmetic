# %% [markdown]
# ![ChamplainLogoTiny.png](data:image/png;base64,...)
# # 420-SN1-RE Programming in Science
# ## **Assignment 1 - Introduction**
#
# The goal of this assignment is to show you how to download/upload notebooks, and how to do basic math with variables and print the result(s).
#
# ### ℹ️ General Assignment Instructions
# 1. Don't modify the boxes that say **"VERIFICATION BOX"** and **text cells** that provide infromation and instruction for questions.
# 2. Answer each question in the box provided that contains the comment __#ANSWER__.
# 3. After completing all your answers, run all the cells at once by selecting Runtime from the menu and then choosing Run all from the menu bar at the top of Google Colab. If you encounter any errors in your output cells or in the verification box, debug and fix the code. Then, rerun all the cells to ensure that all outputs are error-free, correctly solve the question, and match the expected results while passing all verification checks successfully (In case if there is any verification box).
# 4. The VERIFICATION BOX is just an additional cell to help validate selected questions. You also need to verify the output of your code by yourself to make sure your code is correct. Some questions also might not include a VERIFICATION BOX at all.
# 4. If you can't answer a question, just put a **comment** like, `# skip question`, it's possible and normal that you might get stuck on 1 or 2 questions.
# 5. You ARE allowed to discuss the questions with other students if you are stuck! However, you are NOT allowed to copy another student's work.
# 6. You are ONLY allowed to use AI tools for learning purposes. Do not rely solely on AI tools to generate code without understanding it. The instructor may randomly ask students questions about their code, and if you cannot explain your work, you will lose marks on the assignment.
#
# ### ⚠️ Specific Instructions for this Assignment
# * None

# %% [markdown]
# ## Exercise 1.1

# %% [markdown]
# 1. Define a variable used to track the age of a person.  Call it "age" and initialize it to 22.
# 2. Define a variable used to track temperature, call it "temp_celcius" and set it to 21.5.
# 3. Define a variable that can be used to track if a product is broken or not.   Call that variable "defecive" and set it to false.

# %%
# ANSWER
age = 22
temp_celcius = 21.5
defective = False

# %%
# VERIFICATION BOX
assert 'age' in globals(), "The variable age is not defined."
assert 'temp_celcius' in globals(), "The variable temp_celcius is not defined."
assert 'defective' in globals(), "The variable defective is not defined."
assert age == 22, "\"age\" should be an int variable with value of 22"
assert isinstance(age, int), "\"age\" should be an int."
assert temp_celcius == 21.5
assert defective == False, "\"Defective\" should be a boolean variable with value of False"
print ("* CORRECT *")
# Out:
# * CORRECT *

# %% [markdown]
# ## Exercise 1.2
# The following cell contains the tax amount, and the price of an item.   Define a variable called "total_price" and set it to the raw final price of the item including tax.

# %%
# Run this first, then provide your answer below.

# Notes:
# + Add
# - Subtract
# * Multiply
# / Divide
# (A * B) / (B * C) Using parenthesis, if needed.

QC_TAX = 0.09775
item_price = 10.99

# %%
# Answer
total_price = item_price + item_price * QC_TAX

# %%
# Verification Box
assert 'total_price' in globals(), "The variable total1 must be defined, it's the final price with tax."
assert total_price == 12.0642725, "Total price with tax."
print("* Correct *")
# Out:
# * Correct *

# %% [markdown]
# ## Exercise 1.3
# Create a new variable called 'final_price' that looks like "12.06" by using 'total_price' above.
# Read the following article to learn how to truncate a price by using the "round" function:  https://www.w3schools.com/python/ref_func_round.asp

# %%
# Answer
final_price = round(total_price, 2)

# %%
# VERIFICATION BOX
assert 'final_price' in globals(), "The variable final_price must be defined, it's the currency-formatted final price with tax"
assert final_price == 12.06
print("* Correct *")
# Out:
# * Correct *

# %% [markdown]
# ## Exercise 1.4

# %% [markdown]
# Create a formula that calculates/converts the celcius value from farenheit.  Use the variable "C".  Use parentheses when needed, just like you do in mathematical order-of-operations.  (parenthesis, exponents, mult/div, add/subtract).
#
# Use the formula:
#
# $C = \frac{5}{9} \times (F - 32)$

# %%
# Run this first, then provide your answer below.
# 35F is the temperature you want to convert to Celcius

F = 35

# %%
# ANSWER
C = (5/9) * (F -32)

# %%
# VERIFICATION BOX
assert 'C' in globals(), "The variable C must be defined"
assert 'F' in globals(), "The variable F must be defined"
assert F == 35, "F should be 35 (F)"
assert C > 1.66 and C < 1.7, "Value should be around 1.6666666666666667"
print("* Correct *")
# Out:
# * Correct *

# %% [markdown]
# ## Exercise 1.5

# %% [markdown]
# In order to make your day as wonderful as can be, Write a program that prints the following beautiful happy face exactly as it appears.
#
# ![image.png](data:image/png;base64,...)

# %%
# ANSWER

# %% [markdown]
# ## Exercise 1.6

# %% [markdown]
# Write a program that calculates the total amount of a meal purchased at a restaurant.
# The program should ask the user to enter the charge for the food, then calculate the amounts of a 18 percent tip and 15 percent sales tax. Display each of these amounts and the total.
# Produce a bill that looks like this:
#
# ![image.png](data:image/png;base64,...)

# %%
# ANSWER

# %% [markdown]
# ## Exercise 1.7

# %% [markdown]
# Last month, Joe purchased some stock in Acme Software, Inc. Here are the details of the purchase:<br>
# •	The number of shares that Joe purchased was 2,000.  <br>
# •	When Joe purchased the stock, he paid \$40.00 per share.  <br>
# •	Joe paid his stockbroker a commission that amounted to 3 percent of the amount he paid for the stock. <br><br>
# Two weeks later, Joe sold the stock. Here are the details of the sale<br>
# •	The number of shares that Joe sold was 2,000<br>
# •	He sold the stock for $42.75 per share. <br>
# •	He paid his stockbroker another commission that amounted to 3 percent of the amount he received for the stock.<br><br>
# Write a program that displays the following information<br>
# •	The amount of money Joe paid for the stock. <br>
# •	The amount of commission Joe paid his broker when he bought the stock. <br> • The amount for which Joe sold the stock. <br>
# •	The amount of commission Joe paid his broker when he sold the stock. <br>
# •	Display the amount of money that Joe had left when he sold the stock and paid his broker (both times). If this amount is positive, then Joe made a profit. If the amount is negative, then Joe lost money.<br><br>
# Sample output:
#
# ![output01.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercise 1.8

# %%
# ANSWER

# %% [markdown]
# When a bank account pays compound interest, it pays interest not only on the principal amount that was deposited into the account, but also on the interest that has accumulated over time. Suppose you want to deposit some money into a savings account, and let the account earn compound interest for a certain number of years. The formula for calculating the balance of the account after a specified number of years is: <br>
#
# ![image.png](data:image/png;base64,...)
#
#
# The terms in the formula are<br>
# •	A is the amount of money in the account after the specified number of years. <br>
# •	P is the principal amount that was originally deposited into the account. <br>
# •	r is the annual interest rate. <br>
# •	n is the number of times per year that the interest is compounded. <br>
# •	t is the specified number of years.<br><br>
# Write a program that makes the calculation for you. The program should ask the user to input the following:<br>
# •	The amount of principal originally deposited into the account <br>
# •	The annual interest rate paid by the account <br>
# •	The number of times per year that the interest is compounded (For example, if interest is compounded monthly, enter 12. If interest is compounded quarterly, enter 4.) <br>
# •	The number of years the account will be left to earn interest Once the input data has been entered, the program should calculate and display the amount of money that will be in the account after the specified number of years<br><br>
#
# NOTE: The user should enter the interest rate as a percentage. For example, 2 percent would be entered as 2, not as .02. The program will then have to divide the input by 100 to move the decimal point to the correct position<br>
# **Sample output:**<br>
#
#
# ![image.png](data:image/png;base64,...)

# %%
# ANSWER

# %% [markdown]
# <hr>
#
# © 2026 Morteza Khanjanzadeh, Brendan Wood, Haikel Hichri
# Champlain College Saint-Lambert
# **All Rights Reserved.**
# - Use of this notebook without the author's explicit permission is strictly prohibited.
# - This notebook is intended for educational purposes only. Unauthorized modifications, distribution, or reproduction in any form are not allowed.
